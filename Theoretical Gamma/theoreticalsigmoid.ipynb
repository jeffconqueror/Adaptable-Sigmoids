# %%
import numpy as np
from scipy.stats import gamma
import matplotlib.pyplot as plt 
from matplotlib.colors import ListedColormap 
import scipy.optimize as optimization
from scipy.special import expit
from numpy import array
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import math
import scipy

# %%
##dataset
data_location_AT = [r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATER",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATERDD",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATGEO",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATGEOGD",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATHGG",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATSF",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATSFDD",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATSticky",
                 r"file:///Users/rishipadmanabhan/Downloads/DistanceClassifier-master/data/ATOriginal"]

# %%
ER = normalize(pd.read_csv(data_location_AT[0], header = None, sep = ' '))
ER
# Out:
# array([[2.23436983e-03, 1.64236300e-02, 4.05983786e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.26331923e-03, 1.65672609e-02, 3.62887958e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.24196159e-03, 1.64492158e-02, 4.16757237e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.15451052e-03, 1.60291722e-02, 3.88484457e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.25410716e-03, 1.65244707e-02, 4.46268202e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.24464358e-03, 1.64767428e-02, 3.85071093e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a

x = np.arange(-10., 10., 0.1)
sig = sigmoid(x)
plt.plot(x,sig)
z = expit(ER);
plt.plot(ER, z, 'o', label='data')
plt.show()
